# %%
# Import neccessary modules:
import math
from math import log10, floor
from numba import jit
import time
import matplotlib.image as mpimg
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import glob, os
import obspy
from obspy import read
from obspy import Stream
from obspy.core import UTCDateTime
import datetime
import cv2
import re
import scipy
import scipy.signal as signal
# %matplotlib notebook

# %%
#Traveltime curve for icequake 1.27.4

arrival_times=[]
arrival_times_2=[]

    
#Time of arrival at st_tmp[6]-> Node 23.
arrival_times.append(0.305)

#Time of arrival at st_tmp[4]-> Node 20.
arrival_times.append(0.254)

#Time of arrival at st_tmp[5]-> Node 21.
arrival_times.append(0.293)

#Time of arrival at st_tmp[2]-> Node 18.
arrival_times.append(0.404)

#Time of arrival at st_tmp[3]-> Node 19.
arrival_times.append(0.347)

#Time of arrival at st_tmp[8]-> Node 29.
arrival_times.append(0.450)

#Time of arrival at st_tmp[7]-> Node 24.
arrival_times.append(0.383)

#Time of arrival at st_tmp[0]-> Node 14.
arrival_times.append(0.582)

#Time of arrival at st_tmp[1]-> Node 17.
arrival_times.append(1.380)


    
print()
print()
print()


#Time of arrival at st_tmp[6]-> Node 23.
arrival_times_2.append(1.170)

#Time of arrival at st_tmp[4]-> Node 20.
arrival_times_2.append(1.118)

#Time of arrival at st_tmp[5]-> Node 21.
arrival_times_2.append(1.157)

#Time of arrival at st_tmp[2]-> Node 18.
arrival_times_2.append(1.190)

#Time of arrival at st_tmp[3]-> Node 19.
arrival_times_2.append(1.155)

#Time of arrival at st_tmp[8]-> Node 29.
arrival_times_2.append(1.260)

#Time of arrival at st_tmp[7]-> Node 24.
arrival_times_2.append(1.255)

#Time of arrival at st_tmp[0]-> Node 14.
arrival_times_2.append(1.383)

#Time of arrival at st_tmp[1]-> Node 17.
arrival_times_2.append(2.284)


for i in range (9):
    arrival_times[i]=arrival_times[i]-0.221
    arrival_times_2[i]=arrival_times_2[i]-0.221

array_arrivals=np.array(arrival_times)
array_arrivals_2=np.array(arrival_times_2)

distance = [124.21, 287.12, 290.82, 395.98, 444.61, 507.13, 617.43, 694.39, 820.58]
distance_array=np.array(distance)


print(distance_array)
print(array_arrivals)
print(array_arrivals_2)
print(type(distance_array))
print(type(array_arrivals))
print(type(array_arrivals_2))


a, b = np.polyfit(distance_array, array_arrivals, 1)
aa, bb = np.polyfit(distance_array, array_arrivals_2, 1)

plt.figure()
plt.scatter(distance_array, array_arrivals, color='purple', label='first arrivals')
plt.scatter(distance_array, array_arrivals_2, color='mediumvioletred', label='second arrivals')
plt.plot(distance_array, a*distance_array+b, color='royalblue', linestyle='--', linewidth=2, label='first arrivals best fit')
plt.plot(distance_array, aa*distance_array+bb, color='steelblue', linestyle='--', linewidth=2, label='second arrivals best fit')
plt.legend(loc='upper left', prop={'size':8})
plt.xlabel("Distance (metres) from Icequake 1.27.4", color='indigo')
plt.ylabel('Time (seconds) after Icequake origin time', color='indigo')
plt.title("Traveltime curve for Icequake 1.27.4", fontsize = 14, color='indigo')
rounded_a=round(float(a), 4)
rounded_aa=round(float(aa), 4)
rounded_b=round(float(b), 4)
rounded_bb=round(float(bb), 4)
plt.text(600, 0.7,f"y = {rounded_a}x - {abs(rounded_b)}", size=7)
plt.text(600, 1.55,f"y = {rounded_aa}x + {rounded_bb}", size=7)

plt.show()
print(1/a)
print(1/aa)
# Out:
# [124.21 287.12 290.82 395.98 444.61 507.13 617.43 694.39 820.58]
# [0.084 0.033 0.072 0.183 0.126 0.229 0.162 0.361 1.159]
# [0.949 0.897 0.936 0.969 0.934 1.039 1.034 1.162 2.063]
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <img src="data:image/png;base64,..." width="640">
# 828.1203204167864
# 819.6404588139919

# %%
#Traveltime curve for icequake 2.27.1

arrival_times_IC2=[]
arrival_times_IC2_2=[]

#Time of arrival at st_tmp[7]-> Node 24.
arrival_times_IC2.append(7.988)

#Time of arrival at st_tmp[5]-> Node 21.
arrival_times_IC2.append(8.096)

#Time of arrival at st_tmp[8]-> Node 29.
arrival_times_IC2.append(8.110)

#Time of arrival at st_tmp[4]-> Node 20.
arrival_times_IC2.append(8.139)

#Time of arrival at st_tmp[1]-> Node 17.
arrival_times_IC2.append(8.068)

#Time of arrival at st_tmp[6]-> Node 23.
arrival_times_IC2.append(8.263)

#Time of arrival at st_tmp[2]-> Node 18.
arrival_times_IC2.append(8.309)

#Time of arrival at st_tmp[3]-> Node 19.
arrival_times_IC2.append(8.342)

#Time of arrival at st_tmp[0]-> Node 14.
arrival_times_IC2.append(8.357)

    
print()
print()
print()  

#Time of arrival at st_tmp[7]-> Node 24.
arrival_times_IC2_2.append(8.890)

#Time of arrival at st_tmp[5]-> Node 21.
arrival_times_IC2_2.append(8.934)

#Time of arrival at st_tmp[8]-> Node 29.
arrival_times_IC2_2.append(8.933)

#Time of arrival at st_tmp[4]-> Node 20.
arrival_times_IC2_2.append(8.931)

#Time of arrival at st_tmp[1]-> Node 17.
arrival_times_IC2_2.append(8.889)

#Time of arrival at st_tmp[6]-> Node 23.
arrival_times_IC2_2.append(8.972)

#Time of arrival at st_tmp[2]-> Node 18.
arrival_times_IC2_2.append(9.042)

#Time of arrival at st_tmp[3]-> Node 19.
arrival_times_IC2_2.append(9.076)

#Time of arrival at st_tmp[0]-> Node 14.
arrival_times_IC2_2.append(9.077)
    
for i in range (9):
    arrival_times_IC2[i]=arrival_times_IC2[i]-7.965
    arrival_times_IC2_2[i]=arrival_times_IC2_2[i]-7.965

array_arrivals_IC2=np.array(arrival_times_IC2)
array_arrivals_IC2_2=np.array(arrival_times_IC2_2)

distance_IC2 = [89.39, 266.31, 331.29, 550.48, 601.03, 661.18, 763.30, 955.95, 956.48]
distance_array_IC2=np.array(distance_IC2)



array_arrivals_IC2_3=np.array([1.852, 1.907, 1.841, 1.934, 1.95])

distance_IC2_v2 = [89.39, 266.31, 331.29, 550.48, 601.03]
distance_array_IC2_v2=np.array(distance_IC2_v2)


print(array_arrivals_IC2)
print(array_arrivals_IC2_2)
print(distance_array_IC2)
print(array_arrivals_IC2_3)
print(distance_array_IC2_v2)
print(type(array_arrivals_IC2))
print(type(array_arrivals_IC2_2))
print(type(distance_array_IC2))
print(type(array_arrivals_IC2_3))
print(type(distance_array_IC2_v2))



a_IC2, b_IC2 = np.polyfit(distance_array_IC2, array_arrivals_IC2, 1)
aa_IC2, bb_IC2 = np.polyfit(distance_array_IC2, array_arrivals_IC2_2, 1)
aaa_IC2, bbb_IC2 = np.polyfit(distance_array_IC2_v2, array_arrivals_IC2_3, 1)


plt.figure()
plt.scatter(distance_array_IC2, array_arrivals_IC2, color='purple', label='first arrivals')
plt.scatter(distance_array_IC2, array_arrivals_IC2_2, color='mediumvioletred', label='second arrivals')
plt.scatter(distance_array_IC2_v2, array_arrivals_IC2_3, color='blueviolet', label='third arrivals')
plt.plot(distance_array_IC2, a_IC2*distance_array_IC2+b_IC2, color='royalblue', linestyle='--', linewidth=2, label='first arrivals best fit')
plt.plot(distance_array_IC2, aa_IC2*distance_array_IC2+bb_IC2, color='steelblue', linestyle='--', linewidth=2, label='second arrivals best fit')
plt.plot(distance_array_IC2_v2, aaa_IC2*distance_array_IC2_v2+bbb_IC2, color='dodgerblue', linestyle='--', linewidth=2, label='third arrivals\nbest fit')
plt.legend(loc='upper right', prop={'size':6})
plt.xlabel("Distance (metres) from Icequake 2.27.1", color='indigo')
plt.ylabel('Time (seconds) after Icequake origin time', color='indigo')
plt.title("Traveltime curve for Icequake 2.27.1", fontsize = 14, color='indigo')
rounded_a_IC2=round(float(a_IC2), 5)
rounded_aa_IC2=round(float(aa_IC2), 5)
rounded_aaa_IC2=round(float(aaa_IC2), 5)
rounded_b_IC2=round(float(b_IC2), 5)
rounded_bb_IC2=round(float(bb_IC2), 5)
rounded_bbb_IC2=round(float(bbb_IC2), 5)
plt.text(740, 0.2,f"y = {rounded_a_IC2}x - {abs(rounded_b_IC2)}", size=7)
plt.text(740, 0.96,f"y = {rounded_aa_IC2}x + {rounded_bb_IC2}", size=7)
plt.text(400, 1.8,f"y = {rounded_aaa_IC2}x + {rounded_bbb_IC2}", size=7)


plt.show()
print(1/a_IC2)
print(1/aa_IC2)
print(1/aaa_IC2)
# Out:
# [0.023 0.131 0.145 0.174 0.103 0.298 0.344 0.377 0.392]
# [0.925 0.969 0.968 0.966 0.924 1.007 1.077 1.111 1.112]
# [ 89.39 266.31 331.29 550.48 601.03 661.18 763.3  955.95 956.48]
# [1.852 1.907 1.841 1.934 1.95 ]
# [ 89.39 266.31 331.29 550.48 601.03]
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <img src="data:image/png;base64,..." width="640">
# 2458.741591783882
# 4748.211350993771
# 5413.781279109546

# %%
#Traveltime curve for icequake 1.27.4 with reverberation model 

arrival_times=[]
arrival_times_2=[]

    
#Time of arrival at st_tmp[6]-> Node 23.
arrival_times.append(0.305)

#Time of arrival at st_tmp[4]-> Node 20.
arrival_times.append(0.254)

#Time of arrival at st_tmp[5]-> Node 21.
arrival_times.append(0.293)

#Time of arrival at st_tmp[2]-> Node 18.
arrival_times.append(0.404)

#Time of arrival at st_tmp[3]-> Node 19.
arrival_times.append(0.347)

#Time of arrival at st_tmp[8]-> Node 29.
arrival_times.append(0.450)

#Time of arrival at st_tmp[7]-> Node 24.
arrival_times.append(0.383)

#Time of arrival at st_tmp[0]-> Node 14.
arrival_times.append(0.582)

#Time of arrival at st_tmp[1]-> Node 17.
arrival_times.append(1.380)


    
print()
print()
print()


#Time of arrival at st_tmp[6]-> Node 23.
arrival_times_2.append(1.170)

#Time of arrival at st_tmp[4]-> Node 20.
arrival_times_2.append(1.118)

#Time of arrival at st_tmp[5]-> Node 21.
arrival_times_2.append(1.157)

#Time of arrival at st_tmp[2]-> Node 18.
arrival_times_2.append(1.190)

#Time of arrival at st_tmp[3]-> Node 19.
arrival_times_2.append(1.155)

#Time of arrival at st_tmp[8]-> Node 29.
arrival_times_2.append(1.260)

#Time of arrival at st_tmp[7]-> Node 24.
arrival_times_2.append(1.255)

#Time of arrival at st_tmp[0]-> Node 14.
arrival_times_2.append(1.383)

#Time of arrival at st_tmp[1]-> Node 17.
arrival_times_2.append(2.284)


for i in range (9):
    arrival_times[i]=arrival_times[i]-0.221
    arrival_times_2[i]=arrival_times_2[i]-0.221

array_arrivals=np.array(arrival_times)
array_arrivals_2=np.array(arrival_times_2)

distance = [124.21, 287.12, 290.82, 395.98, 444.61, 507.13, 617.43, 694.39, 820.58]
distance_array=np.array(distance)


print(distance_array)
print(array_arrivals)
print(array_arrivals_2)
print(type(distance_array))
print(type(array_arrivals))
print(type(array_arrivals_2))


a, b = np.polyfit(distance_array, array_arrivals, 1)
aa, bb = np.polyfit(distance_array, array_arrivals_2, 1)

model_arrivals_2 = [0] * len(distance_array)
for i in range (len(distance_array)):
    model_arrivals_2[i] = 2*math.sqrt(150**2+(0.5*distance_array[i])**2)/819.6404588139919
model_arrivals_2_array = np.array(model_arrivals_2)
    

plt.figure()
plt.scatter(distance_array, array_arrivals, color='purple', label='first arrivals')
plt.scatter(distance_array, array_arrivals_2, color='mediumvioletred', label='second arrivals')
plt.plot(distance_array, a*distance_array+b, color='royalblue', linestyle='--', linewidth=2, label='first arrivals best fit')
plt.plot(distance_array, aa*distance_array+bb, color='steelblue', linestyle='--', linewidth=2, label='second arrivals best fit')
plt.plot(distance_array, model_arrivals_2_array, color='plum', linestyle='--', linewidth=2, label='reverberation model second arrivals')
plt.legend(loc='upper left', prop={'size':8})
plt.xlabel("Distance (metres) from Icequake 1.27.4", color='indigo')
plt.ylabel('Time (seconds) after Icequake origin time', color='indigo')
plt.title("Traveltime curve for Icequake 1.27.4", fontsize = 14, color='indigo')
rounded_a=round(float(a), 4)
rounded_aa=round(float(aa), 4)
rounded_b=round(float(b), 4)
rounded_bb=round(float(bb), 4)
plt.text(600, 0.7,f"y = {rounded_a}x - {abs(rounded_b)}", size=7)
plt.text(600, 1.55,f"y = {rounded_aa}x + {rounded_bb}", size=7)

plt.show()
print(1/a)
print(1/aa)
# Out:
# [124.21 287.12 290.82 395.98 444.61 507.13 617.43 694.39 820.58]
# [0.084 0.033 0.072 0.183 0.126 0.229 0.162 0.361 1.159]
# [0.949 0.897 0.936 0.969 0.934 1.039 1.034 1.162 2.063]
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <img src="data:image/png;base64,..." width="640">
# 828.1203204167864
# 819.6404588139919

# %%
#Traveltime curve for icequake 2.27.1 with reverberation model

arrival_times_IC2=[]
arrival_times_IC2_2=[]

#Time of arrival at st_tmp[7]-> Node 24.
arrival_times_IC2.append(7.988)

#Time of arrival at st_tmp[5]-> Node 21.
arrival_times_IC2.append(8.096)

#Time of arrival at st_tmp[8]-> Node 29.
arrival_times_IC2.append(8.110)

#Time of arrival at st_tmp[4]-> Node 20.
arrival_times_IC2.append(8.139)

#Time of arrival at st_tmp[1]-> Node 17.
arrival_times_IC2.append(8.068)

#Time of arrival at st_tmp[6]-> Node 23.
arrival_times_IC2.append(8.263)

#Time of arrival at st_tmp[2]-> Node 18.
arrival_times_IC2.append(8.309)

#Time of arrival at st_tmp[3]-> Node 19.
arrival_times_IC2.append(8.342)

#Time of arrival at st_tmp[0]-> Node 14.
arrival_times_IC2.append(8.357)

    
print()
print()
print()  

#Time of arrival at st_tmp[7]-> Node 24.
arrival_times_IC2_2.append(8.890)

#Time of arrival at st_tmp[5]-> Node 21.
arrival_times_IC2_2.append(8.934)

#Time of arrival at st_tmp[8]-> Node 29.
arrival_times_IC2_2.append(8.933)

#Time of arrival at st_tmp[4]-> Node 20.
arrival_times_IC2_2.append(8.931)

#Time of arrival at st_tmp[1]-> Node 17.
arrival_times_IC2_2.append(8.889)

#Time of arrival at st_tmp[6]-> Node 23.
arrival_times_IC2_2.append(8.972)

#Time of arrival at st_tmp[2]-> Node 18.
arrival_times_IC2_2.append(9.042)

#Time of arrival at st_tmp[3]-> Node 19.
arrival_times_IC2_2.append(9.076)

#Time of arrival at st_tmp[0]-> Node 14.
arrival_times_IC2_2.append(9.077)
    
for i in range (9):
    arrival_times_IC2[i]=arrival_times_IC2[i]-7.965
    arrival_times_IC2_2[i]=arrival_times_IC2_2[i]-7.965

array_arrivals_IC2=np.array(arrival_times_IC2)
array_arrivals_IC2_2=np.array(arrival_times_IC2_2)

distance_IC2 = [89.39, 266.31, 331.29, 550.48, 601.03, 661.18, 763.30, 955.95, 956.48]
distance_array_IC2=np.array(distance_IC2)



array_arrivals_IC2_3=np.array([1.852, 1.907, 1.841, 1.934, 1.95])

distance_IC2_v2 = [89.39, 266.31, 331.29, 550.48, 601.03]
distance_array_IC2_v2=np.array(distance_IC2_v2)


print(array_arrivals_IC2)
print(array_arrivals_IC2_2)
print(distance_array_IC2)
print(array_arrivals_IC2_3)
print(distance_array_IC2_v2)
print(type(array_arrivals_IC2))
print(type(array_arrivals_IC2_2))
print(type(distance_array_IC2))
print(type(array_arrivals_IC2_3))
print(type(distance_array_IC2_v2))



a_IC2, b_IC2 = np.polyfit(distance_array_IC2, array_arrivals_IC2, 1)
aa_IC2, bb_IC2 = np.polyfit(distance_array_IC2, array_arrivals_IC2_2, 1)
aaa_IC2, bbb_IC2 = np.polyfit(distance_array_IC2_v2, array_arrivals_IC2_3, 1)



model_arrivals_2_IC2 = [0] * len(distance_array_IC2)
for i in range (len(distance_array_IC2)):
    model_arrivals_2_IC2[i] = 2*math.sqrt(150**2+(0.5*distance_array_IC2[i])**2)/4748.211350993771
model_arrivals_2_IC2_array = np.array(model_arrivals_2_IC2)


model_arrivals_3_IC2 = [0] * len(distance_array_IC2)
for i in range (len(distance_array_IC2)):
    model_arrivals_3_IC2[i] = 4*math.sqrt(150**2+(0.25*distance_array_IC2[i])**2)/5413.781279109546
model_arrivals_3_IC2_array = np.array(model_arrivals_3_IC2)


plt.figure()
plt.scatter(distance_array_IC2, array_arrivals_IC2, color='purple', label='first arrivals')
plt.scatter(distance_array_IC2, array_arrivals_IC2_2, color='mediumvioletred', label='second arrivals')
plt.scatter(distance_array_IC2_v2, array_arrivals_IC2_3, color='blueviolet', label='third arrivals')
plt.plot(distance_array_IC2, a_IC2*distance_array_IC2+b_IC2, color='royalblue', linestyle='--', linewidth=2, label='first arrivals best fit')
plt.plot(distance_array_IC2, aa_IC2*distance_array_IC2+bb_IC2, color='steelblue', linestyle='--', linewidth=2, label='second arrivals best fit')
plt.plot(distance_array_IC2_v2, aaa_IC2*distance_array_IC2_v2+bbb_IC2, color='dodgerblue', linestyle='--', linewidth=2, label='third arrivals best fit')
plt.plot(distance_array_IC2, model_arrivals_2_IC2_array, color='plum', linestyle='--', linewidth=2, label='reverberation model\nsecond arrivals')
plt.plot(distance_array_IC2, model_arrivals_3_IC2_array, color='orchid', linestyle='--', linewidth=2, label='reverberation model\nthird arrivals')
plt.legend(loc='upper right', prop={'size':6})
plt.xlabel("Distance (metres) from Icequake 2.27.1", color='indigo')
plt.ylabel('Time (seconds) after Icequake origin time', color='indigo')
plt.title("Traveltime curve for Icequake 2.27.1", fontsize = 14, color='indigo')
rounded_a_IC2=round(float(a_IC2), 5)
rounded_aa_IC2=round(float(aa_IC2), 5)
rounded_aaa_IC2=round(float(aaa_IC2), 5)
rounded_b_IC2=round(float(b_IC2), 5)
rounded_bb_IC2=round(float(bb_IC2), 5)
rounded_bbb_IC2=round(float(bbb_IC2), 5)
plt.text(740, 0.2,f"y = {rounded_a_IC2}x - {abs(rounded_b_IC2)}", size=7)
plt.text(740, 0.96,f"y = {rounded_aa_IC2}x + {rounded_bb_IC2}", size=7)
plt.text(400, 1.8,f"y = {rounded_aaa_IC2}x + {rounded_bbb_IC2}", size=7)


plt.show()
print(1/a_IC2)
print(1/aa_IC2)
print(1/aaa_IC2)
# Out:
# [0.023 0.131 0.145 0.174 0.103 0.298 0.344 0.377 0.392]
# [0.925 0.969 0.968 0.966 0.924 1.007 1.077 1.111 1.112]
# [ 89.39 266.31 331.29 550.48 601.03 661.18 763.3  955.95 956.48]
# [1.852 1.907 1.841 1.934 1.95 ]
# [ 89.39 266.31 331.29 550.48 601.03]
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <img src="data:image/png;base64,..." width="640">
# 2458.741591783882
# 4748.211350993771
# 5413.781279109546
